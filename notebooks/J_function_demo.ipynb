# %% [markdown]
# # J Function Demo (Ratio of F and G)

# %%
from point_process_utils import Point_Process, Point, hom_poisspp
from summary_statistics import F_hat, G_hat, J_hat
import seaborn as sbn
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Create rectangular window.

# %%
window = {'x_min': 0.0, 'x_max': 100.0, 'y_min':0.0, 'y_max': 100.0}

# %% [markdown]
# Generate a homogeneous Poisson Process, with intensity 0.05. Check to see how many points have been generated.

# %%
pp = hom_poisspp(0.2, window)                                               
pp.num_points
# Out:
# 1963

# %% [markdown]
# Let's display the point process

# %%
pp.display()

# %% [markdown]
# Choose domain to calculate $F$ and $G$ on.

# %%
r = np.linspace(0, 5, 200)

# %% [markdown]
# Call the function with the option to plot the result. Points returned in array. `num_F_sampled_points` chooses how many points in the domain used to estimate $F$.

# %%
J_hat_array = J_hat(pp, r, num_F_sampled_points=1000, plot=True)
